# %%
import pandas as pd

# %%
df_Fill = pd.read_excel("./dataSet/cleanedData.xlsx")

# %%
df_Fill.iloc[:, 5:69] = (
    df_Fill.iloc[:, 5:69].astype(float).apply(pd.to_numeric, errors='coerce')/10
)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6100\2268286926.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        19.6
# 1        22.0
# 2        20.6
# 3        22.4
# 4        20.2
#          ...
# 16065    19.8
# 16066    16.8
# 16067    20.2
# 16068    28.0
# 16069    28.0
# Name: BSL/S05, Length: 16070, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_Fill.iloc[:, 5:69] = (
# C:\Users\User\AppData\Local\Temp\ipykernel_6100\2268286926.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0        20.2
# 1        22.0
# 2        20.8
# 3        22.2
# 4        20.8
#          ...
# 16065    20.2
# 16066    18.2
# 16067    20.4
# 16068    28.8
# 16069    28.8
# ...

# %%
df_Fill.head(5)
# Out:
#    Station  BARISAL    Month  Date  Hour  BSL/S05   S10   S20   S30   S50  \
# 0  Barisal     2001  January   1.0     0     19.6  20.2  21.8  21.6  21.4
# 1  Barisal     2001  January   1.0    12     22.0  22.0  22.2  22.2  21.6
# 2  Barisal     2001  January   2.0     0     20.6  20.8  21.8  21.6  21.2
# 3  Barisal     2001  January   2.0    12     22.4  22.2  22.0  21.8  21.4
# 4  Barisal     2001  January   3.0     0     20.2  20.8  21.8  21.8  21.6
#
#    ...   RNP  ST10.10  ST20.10  ST30.10  ST50.10   SML  ST10.11  ST20.11  \
# 0  ...  16.8     18.0     19.0     20.2     20.6  16.9     18.5     20.5
# 1  ...  19.6     19.9     20.0     20.2     20.9  25.6     25.0     23.2
# 2  ...  17.2     18.4     19.3     20.0     20.8  18.2     19.5     21.2
# 3  ...  21.8     21.6     20.6     20.6     20.9  27.2     26.3     24.0
# 4  ...  17.6     18.8     20.0     20.6     21.2  18.0     19.4     21.0
#
#    ST30.11  ST50.11
# 0     21.8      222
# 1     22.6      220
# ...

# %%
df_Fill.to_csv('filename.csv', index=False)
